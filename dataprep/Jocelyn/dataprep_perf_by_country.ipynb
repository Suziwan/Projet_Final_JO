# %% [markdown]
# # Data preparation - Performance aux J.O. par pays
# ---

# %%
import pandas as pd
df_jo = pd.read_csv("athlete_events.csv", sep = ",")
df_jo.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ### Performances par pays, toutes éditions confondues

# %%
df = df_jo

# Données des jeux d'été uniquement
df = df.loc[df['Season'] == "Summer"]

# Sélection des colonnes à garder
df= df.loc[:, ["Team", "NOC", "Year", "Sport", "Event", "Medal"]]

# Suppression des valeurs nulles : athlètes n'ayant pas eu de médaille
df = df.dropna()

#On conserve une seule médaille par event
df=df.groupby(["Year","Event"]).first()
df=df.reset_index()
display(df)
# Out:
#       Year                                           Event           Team  \
# 0     1896                    Athletics Men's 1,500 metres  United States
# 1     1896                      Athletics Men's 100 metres  United States
# 2     1896              Athletics Men's 110 metres Hurdles  United States
# 3     1896                      Athletics Men's 400 metres  United States
# 4     1896                      Athletics Men's 800 metres        Hungary
# ...    ...                                             ...            ...
# 5211  2016          Wrestling Women's Flyweight, Freestyle     Azerbaijan
# 5212  2016        Wrestling Women's Heavyweight, Freestyle         Russia
# 5213  2016  Wrestling Women's Light-Heavyweight, Freestyle          Japan
# 5214  2016        Wrestling Women's Lightweight, Freestyle        Tunisia
# 5215  2016       Wrestling Women's Middleweight, Freestyle          Japan
#
#       NOC      Sport   Medal
# 0     USA  Athletics  Silver
# 1     USA  Athletics    Gold
# 2     USA  Athletics    Gold
# 3     USA  Athletics    Gold
# 4     HUN  Athletics  Silver
# ...   ...        ...     ...
# 5211  AZE  Wrestling  Silver
# 5212  RUS  Wrestling  Bronze
# 5213  JPN  Wrestling    Gold
# 5214  TUN  Wrestling  Bronze
# 5215  JPN  Wrestling    Gold
#
# [5216 rows x 6 columns]
